# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
import mysql.connector

# %%
MONGO_URI = "mongodb+srv://hungqlworking:IC96WUPzMTJzCkI1@cluster0.temagzq.mongodb.net/netflix_DB?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(MONGO_URI)
db = client["netflix_DB"]
collection = db["searchhistories"]
data = list(collection.find()) 
df = pd.DataFrame(data)

# %%
df
# Out:
#                          _id                    userId       id  \
# 0   66cdbefda76478c2f182da32  66cdbedea76478c2f182da09  1125206
# 1   66cdbf5aa76478c2f182da49  66cdbedea76478c2f182da09     1434
# 2   66cdbf72a76478c2f182da52  66cdbedea76478c2f182da09  1213319
# 3   66ceaa0e5568e9efbc5bc451  66ceaa0e5568e9efbc5bc450     1083
# 4   66ceaa0f5568e9efbc5bc453  66ceaa0f5568e9efbc5bc452     1372
# ..                       ...                       ...      ...
# 57  66d97fc3aa7db0cbd2275835  66d97fc3aa7db0cbd2275833     1805
# 58  66d97fc3aa7db0cbd2275836  66d97fc3aa7db0cbd2275833     1550
# 59  66d97fc3aa7db0cbd2275837  66d97fc3aa7db0cbd2275833     1012
# 60  66d97fc3aa7db0cbd2275838  66d97fc3aa7db0cbd2275833     2000
# 61  66d97fc3aa7db0cbd2275839  66d97fc3aa7db0cbd2275833     1410
#
#                                image               title searchType  \
# 0   /vPXgslVTOsKm8P26ksLYZsGpVI3.jpg             bigbang      movie
# ...

# %%
new_df = df[['userId','searchType','keyword','createdAt']]

# %%
new_df
# Out:
#                       userId searchType             keyword  \
# 0   66cdbedea76478c2f182da09      movie             bigbang
# 1   66cdbedea76478c2f182da09         tv          family guy
# 2   66cdbedea76478c2f182da09     person             Ronaldo
# 3   66ceaa0e5568e9efbc5bc450      movie        forrest gump
# 4   66ceaa0f5568e9efbc5bc452         tv     stranger things
# ..                       ...        ...                 ...
# 57  66d97fc3aa7db0cbd2275833     person  scarlett johansson
# 58  66d97fc3aa7db0cbd2275833      movie           inception
# 59  66d97fc3aa7db0cbd2275833         tv           chernobyl
# 60  66d97fc3aa7db0cbd2275833     person       anne hathaway
# 61  66d97fc3aa7db0cbd2275833      movie     the dark knight
#
#                  createdAt
# 0  2024-08-27 11:56:45.335
# 1  2024-08-27 11:58:18.723
# 2  2024-08-27 11:58:42.816
# 3  2024-08-28 11:39:42.463
# 4  2024-08-28 11:39:43.186
# ..                     ...
# 57 2024-09-05 16:54:11.660
# ...
